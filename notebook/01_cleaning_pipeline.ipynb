# %% [markdown]
# # 01 · Cleaning pipeline
#
# Este notebook prepara el corpus común del proyecto. Su salida principal es `data/poems_processed.csv`, que funciona como cache de texto procesado para evitar repetir `spaCy` en cada notebook.
#
# Para una visualización completa, se recomienda usar **nbviewer**:
#
# - [01_cleaning_pipeline.ipynb (nbviewer)](https://nbviewer.org/github/HubertRonald/VersoVector/blob/main/notebook/01_cleaning_pipeline.ipynb)

# %%
from __future__ import annotations
import sys
from pathlib import Path

# Permite importar modules/ y utils/ cuando el notebook se ejecuta desde notebook/
sys.path.insert(0, '..')

# %load_ext autoreload
# %autoreload 2

# python
import csv
import os
import ssl

import pandas as pd
from inspect import cleandoc

# utils, modules
from utils import Constants
from modules.preprocessing import (
    preprocess, 
    normalize_poetry_columns
)
from modules.io import data_path, display_path

# typings
from pandas import DataFrame as PandasDF
from typing import Dict, List

# setup
pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('max_colwidth', None)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# cargar el dataset sklearn
if not os.environ.get('CI'):
    ssl._create_default_https_context =\
        ssl._create_unverified_context

# input base
poetry_fundation_data: Path = data_path('PoetryFoundationData.csv')
external_poetry_sources: List[Dict] = [
    {
        "path": data_path("vallejo_poems_en.csv"),
        "source": "cesar_vallejo",
        "poet": "César Vallejo",
        "corpus_role": "external",
    },
    # Ejemplo futuro:
    # {
    #     "path": data_path("valera_poems_en.csv"),
    #     "source": "blanca_valera",
    #     "poet": "Blanca Valera",
    #     "corpus_role": "external",
    # },
]

# outputs / cache
poetry_fundation_cleaned: Path = data_path("CleanedPoetryFoundationData.csv")
poems_processed_cache: Path = data_path("poems_processed.csv")

# %%
setup_load_input: Dict = dict(
    sep=Constants.COMMA_STR,
    encoding=Constants.ENCODING
)

setup_load_pipe: Dict = dict(
    sep=Constants.PIPE_STR,
    quotechar=Constants.QUOTECHAR_STR,
    quoting=csv.QUOTE_NONNUMERIC,
    encoding=Constants.ENCODING,
)

setup_save_pipe: Dict = dict(
    sep=Constants.PIPE_STR,
    quotechar=Constants.QUOTECHAR_STR,
    quoting=csv.QUOTE_NONNUMERIC,
    encoding=Constants.ENCODING,
    index=False,
)

FORCE_REBUILD_POETRY_CLEANED: bool = False
FORCE_REBUILD_PROCESSED_CACHE: bool = False

USE_PROCESSED_CACHE = (
    poems_processed_cache.is_file()
    and not FORCE_REBUILD_PROCESSED_CACHE
    and not FORCE_REBUILD_POETRY_CLEANED
)

# %%
# intentar cargar el cache final
if USE_PROCESSED_CACHE:
    print(f"Cargando cache combinado existente: {display_path(poems_processed_cache)}")

    new_poems_df: PandasDF = pd.read_csv(
        str(poems_processed_cache),
        **setup_load_pipe,
    )

    new_poems_df = normalize_poetry_columns(new_poems_df)

    if "source" not in new_poems_df.columns:
        new_poems_df["source"] = Constants.UNKNOWN

    if "corpus_role" not in new_poems_df.columns:
        new_poems_df["corpus_role"] = Constants.UNKNOWN

    if "poem_raw" not in new_poems_df.columns:
        new_poems_df["poem_raw"] = new_poems_df["poem"].astype(str)

    if "poem_processed" not in new_poems_df.columns:
        raise ValueError(
            "El cache existe, pero no contiene la columna poem_processed. "
            "Ejecuta con FORCE_REBUILD_PROCESSED_CACHE=True."
        )

else:
    print(
        "No existe cache combinado o se solicitó reconstrucción. "
        "Se construirá desde archivos fuente..."
    )

    if not poetry_fundation_data.is_file():
        raise FileNotFoundError(
            cleandoc(f"""
            El archivo {poetry_fundation_data} no existe.

            Por favor, descargue PoetryFoundationData.csv desde:
            https://www.kaggle.com/datasets/abhinavwalia95/poetryfoundationorg

            y colóquelo en la carpeta ./data/
            """)
        )

    missing_external_files = [
        item["path"]
        for item in external_poetry_sources
        if not item["path"].is_file()
    ]

    if missing_external_files:
        raise FileNotFoundError(
            cleandoc(f"""
            No existen los siguientes archivos externos:

            {missing_external_files}

            Verifique que estén disponibles en ./data/
            """)
        )
# Out:
# No existe cache combinado o se solicitó reconstrucción. Se construirá desde archivos fuente...

# %%
# Construir o cargar Poetry Foundation limpio
if not USE_PROCESSED_CACHE:

    if poetry_fundation_cleaned.is_file() and not FORCE_REBUILD_POETRY_CLEANED:
        print(f"Cargando Poetry Foundation limpio desde: {display_path(poetry_fundation_cleaned)}")

        poetry_df: PandasDF = pd.read_csv(
            str(poetry_fundation_cleaned),
            **setup_load_pipe,
        )

        poetry_df = normalize_poetry_columns(poetry_df)

    else:
        print("Procesando PoetryFoundationData.csv desde archivo crudo...")

        poetry_df: PandasDF = (
            pd.read_csv(
                poetry_fundation_data,
                usecols=lambda col: "unnamed" not in col.lower(),
                **setup_load_input,
            )
            .dropna(subset=["Title", "Poem"])
            .reset_index(drop=True)
        )

        poetry_df = normalize_poetry_columns(poetry_df)
        
        poetry_df["source"] = "poetry_foundation"
        poetry_df["corpus_role"] = "reference"

        poetry_df["poem_processed"] = (
            poetry_df["poem_raw"]
            .astype(str)
            .apply(preprocess)
        )

        poetry_df.to_csv(
            str(poetry_fundation_cleaned),
            **setup_save_pipe,
        )

        print(f"Archivo generado: {display_path(poetry_fundation_cleaned)}")
# Out:
# Procesando PoetryFoundationData.csv desde archivo crudo...
# Archivo generado: /VersoVector/data/CleanedPoetryFoundationData.csv

# %%
# Asegurar columnas sin reprocesar de mas
if not USE_PROCESSED_CACHE:

    poetry_df = normalize_poetry_columns(poetry_df)

    if "source" not in poetry_df.columns:
        poetry_df["source"] = "poetry_foundation"

    if "corpus_role" not in poetry_df.columns:
        poetry_df["corpus_role"] = "reference"

    if "poem_processed" not in poetry_df.columns:
        poetry_df["poem_processed"] = ""

    missing_processed_mask = (
        poetry_df["poem_processed"].isna()
        | poetry_df["poem_processed"].astype(str).str.strip().eq("")
    )

    if missing_processed_mask.any():
        print(
            f"Se procesarán {missing_processed_mask.sum()} poemas "
            "de Poetry Foundation sin poem_processed..."
        )

        poetry_df.loc[missing_processed_mask, "poem_processed"] = (
            poetry_df.loc[missing_processed_mask, "poem_raw"]
            .astype(str)
            .apply(preprocess)
        )

        poetry_df.to_csv(
            str(poetry_fundation_cleaned),
            **setup_save_pipe,
        )

        print(f"Archivo actualizado: {display_path(poetry_fundation_cleaned)}")

    display(poetry_df.head(2))
    print(poetry_df.shape)
# Out:
# Se procesarán 107 poemas de Poetry Foundation sin poem_processed...
# Archivo actualizado: /VersoVector/data/CleanedPoetryFoundationData.csv
#                                 title  \
# 0  objects used to prop open a window
# 1                      the new church
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               poem  \
# ...

# %%
# Cargar poetas externos de forma general
if not USE_PROCESSED_CACHE:

    external_frames: List[PandasDF] = []

    for item in external_poetry_sources:
        external_df: PandasDF = pd.read_csv(
            str(item["path"]),
            **setup_load_pipe,
        )

        external_df = external_df.rename(
            columns={
                col: (
                    col
                    .strip()
                    .lower()
                    .replace(Constants.SPACE_STR, Constants.UNDERLINE)
                )
                for col in external_df.columns
            }
        )

        external_df = (
            external_df
            .dropna(subset=["title", "poem"])
            .reset_index(drop=True)
        )

        external_df["poet"] = item["poet"]
        external_df["tags"] = [[] for _ in range(len(external_df))]

        external_df = normalize_poetry_columns(external_df)

        external_df["source"] = item["source"]
        external_df["corpus_role"] = item.get("corpus_role", "external")

        external_df["poem_processed"] = (
            external_df["poem_raw"]
            .astype(str)
            .apply(preprocess)
        )

        external_frames.append(external_df)

    external_poems_df: PandasDF = (
        pd.concat(external_frames, ignore_index=True)
        if external_frames
        else pd.DataFrame()
    )

# %%
# Construir new_poems_df
if not USE_PROCESSED_CACHE:

    column_name: List[str] = [
        "title",
        "title_raw",
        "poet",
        "poet_raw",
        "poem",
        "tags",
        "source",
        "corpus_role",
        "poem_raw",
        "poem_processed",
    ]

    frames_to_concat: List[PandasDF] = [
        poetry_df[column_name],
    ]

    if not external_poems_df.empty:
        frames_to_concat.append(external_poems_df[column_name])

    new_poems_df: PandasDF = (
        pd.concat(
            frames_to_concat,
            ignore_index=True,
        )
        .dropna(subset=["title", "poem_processed"])
        .reset_index(drop=True)
    )

    new_poems_df.to_csv(
        str(poems_processed_cache),
        **setup_save_pipe,
    )

    print(f"Cache combinado generado: {display_path(poems_processed_cache)}")

display(new_poems_df.head(5))
print(new_poems_df.shape)

display(
    pd.DataFrame(
        new_poems_df[["corpus_role", "source", "poet"]]
        .value_counts()
        .head(20)
    )
)
