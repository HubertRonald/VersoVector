# %%
from __future__ import annotations
import sys
from pathlib import Path

# Permite importar modules/ y utils/ cuando el notebook se ejecuta desde notebook/
sys.path.insert(0, '..')

# %load_ext autoreload
# %autoreload 2

# python
import ast
import csv
import os
import ssl

import pandas as pd
from inspect import cleandoc

# utils, modules
from utils import Constants
from modules.preprocessing import (
    clean,
    preprocess, 
    preprocess_tags, 
    normalize_poetry_columns
)
from modules.io import data_path, save_csv, load_csv

# typings
from pandas import DataFrame as PandasDF
from typing import Dict, List

# setup
pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('max_colwidth', None)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# cargar el dataset sklearn
if not os.environ.get('CI'):
    ssl._create_default_https_context =\
        ssl._create_unverified_context

# input base
poetry_fundation_data: Path = data_path('PoetryFoundationData.csv')
external_poetry_sources: List[Dict] = [
    {
        "path": data_path("vallejo_poems_en.csv"),
        "source": "cesar_vallejo",
        "poet": "César Vallejo",
        "corpus_role": "external",
    },
    # Ejemplo futuro:
    # {
    #     "path": data_path("neruda_poems_en.csv"),
    #     "source": "pablo_neruda",
    #     "poet": "Pablo Neruda",
    #     "corpus_role": "external",
    # },
]

# outputs / cache
poetry_fundation_cleaned: Path = data_path("CleanedPoetryFoundationData.csv")
poems_processed_cache: Path = data_path("poems_processed.csv")

# %%
setup_load_input: Dict = dict(
    sep=Constants.COMMA_STR,
    encoding=Constants.ENCODING
)

setup_load_pipe: Dict = dict(
    sep=Constants.PIPE_STR,
    quotechar=Constants.QUOTECHAR_STR,
    quoting=csv.QUOTE_NONNUMERIC,
    encoding=Constants.ENCODING,
)

setup_save_pipe: Dict = dict(
    sep=Constants.PIPE_STR,
    quotechar=Constants.QUOTECHAR_STR,
    quoting=csv.QUOTE_NONNUMERIC,
    encoding=Constants.ENCODING,
    index=False,
)

FORCE_REBUILD_POETRY_CLEANED: bool = False
FORCE_REBUILD_PROCESSED_CACHE: bool = False

# %%
# intentar cargar el cache final
if poems_processed_cache.is_file() and not FORCE_REBUILD_PROCESSED_CACHE:
    print(f"Cargando cache combinado existente: {poems_processed_cache}")

    new_poems_df: PandasDF = pd.read_csv(
        str(poems_processed_cache),
        **setup_load_pipe,
    )

    new_poems_df["tags"] = preprocess_tags(new_poems_df["tags"])
    
    if "title_raw" not in new_poems_df.columns:
        new_poems_df["title_raw"] = new_poems_df["title"].astype(str)

    new_poems_df["title"] = new_poems_df["title"].astype(str).apply(clean)

else:
    print("No existe cache combinado. Se construirá desde los archivos fuente...")

    if not poetry_fundation_data.is_file():
        raise FileNotFoundError(
            cleandoc(f"""
            El archivo {poetry_fundation_data} no existe.

            Por favor, descargue PoetryFoundationData.csv desde:
            https://www.kaggle.com/datasets/abhinavwalia95/poetryfoundationorg

            y coloquelo en la carpeta ./data/
            """)
        )

    missing_external_files = [
        item["path"]
        for item in external_poetry_sources
        if not item["path"].is_file()
    ]

    if missing_external_files:
        raise FileNotFoundError(
            cleandoc(f"""
            No existen los siguientes archivos externos:

            {missing_external_files}

            Verifique que esten disponibles en ./data/
            """)
        )
# Out:
# Cargando cache combinado existente: /Users/ronaldmendoza/Documents/Documents/Repos/GitHub/projects/_hubertronald/VersoVector/data/poems_processed.csv

# %%
# Construir o cargar Poetry Foundation limpio
if not (poems_processed_cache.is_file() and not FORCE_REBUILD_PROCESSED_CACHE):

    if poetry_fundation_cleaned.is_file() and not FORCE_REBUILD_POETRY_CLEANED:
        print(f"Cargando Poetry Foundation limpio desde: {poetry_fundation_cleaned}")

        poetry_df: PandasDF = pd.read_csv(
            str(poetry_fundation_cleaned),
            **setup_load_pipe,
        )

        poetry_df = normalize_poetry_columns(poetry_df)

    else:
        print("Procesando PoetryFoundationData.csv desde archivo crudo...")

        poetry_df: PandasDF = (
            pd.read_csv(
                poetry_fundation_data,
                usecols=lambda col: "unnamed" not in col.lower(),
                **setup_load_input,
            )
            .dropna(subset=["Title", "Poem"])
            .reset_index(drop=True)
        )

        poetry_df = normalize_poetry_columns(poetry_df)
        
        poetry_df["source"] = "poetry_foundation"
        poetry_df["corpus_role"] = "reference"
        
        # Conservar título original y crear título limpio para joins, 
        # busquedas y visualizacion controlada
        poetry_df["title_raw"] = poetry_df["title"].astype(str)
        poetry_df["title"] = poetry_df["title_raw"].apply(clean)

        poetry_df["poem_raw"] = poetry_df["poem"].astype(str)

        poetry_df["poem_processed"] = (
            poetry_df["poem_raw"]
            .astype(str)
            .apply(preprocess)
        )

        poetry_df.to_csv(
            str(poetry_fundation_cleaned),
            **setup_save_pipe,
        )

        print(f"Archivo generado: {poetry_fundation_cleaned}")

# %%
# Asegurar columnas sin reprocesar de mas
if not (poems_processed_cache.is_file() and not FORCE_REBUILD_PROCESSED_CACHE):

    if "source" not in poetry_df.columns:
        poetry_df["source"] = "poetry_foundation"

    if "corpus_role" not in poetry_df.columns:
        poetry_df["corpus_role"] = "reference"

    if "poem_raw" not in poetry_df.columns:
        poetry_df["poem_raw"] = poetry_df["poem"].astype(str)

    if "poem_processed" not in poetry_df.columns:
        poetry_df["poem_processed"] = ""

    missing_processed_mask = (
        poetry_df["poem_processed"].isna()
        | poetry_df["poem_processed"].astype(str).str.strip().eq("")
    )

    if missing_processed_mask.any():
        print(
            f"Se procesarán {missing_processed_mask.sum()} poemas "
            "de Poetry Foundation sin poem_processed..."
        )

        poetry_df.loc[missing_processed_mask, "poem_processed"] = (
            poetry_df.loc[missing_processed_mask, "poem_raw"]
            .astype(str)
            .apply(preprocess)
        )

        poetry_df.to_csv(
            str(poetry_fundation_cleaned),
            **setup_save_pipe,
        )

        print(f"Archivo actualizado: {poetry_fundation_cleaned}")

    display(poetry_df.head(2))
    print(poetry_df.shape)

# %%
# Cargar poetas externos de forma general
if not (poems_processed_cache.is_file() and not FORCE_REBUILD_PROCESSED_CACHE):

    external_frames: List[PandasDF] = []

    for item in external_poetry_sources:
        external_df: PandasDF = (
            pd.read_csv(
                str(item["path"]),
                **setup_load_pipe,
            )
            .dropna(subset=["title", "poem"])
            .reset_index(drop=True)
        )

        external_df = external_df.rename(
            columns={
                col: (
                    col
                    .strip()
                    .lower()
                    .replace(Constants.SPACE_STR, Constants.UNDERLINE)
                )
                for col in external_df.columns
            }
        )
        
        external_df["title_raw"] = external_df["title"].astype(str)
        external_df["title"] = external_df["title_raw"].apply(clean)

        external_df["source"] = item["source"]
        external_df["poet"] = item["poet"]
        external_df["corpus_role"] = item.get("corpus_role", "external")
        external_df["tags"] = [[] for _ in range(len(external_df))]
        external_df["poem_raw"] = external_df["poem"].astype(str)

        external_df["poem_processed"] = (
            external_df["poem_raw"]
            .astype(str)
            .apply(preprocess)
        )

        external_frames.append(external_df)

    external_poems_df: PandasDF = pd.concat(
        external_frames,
        ignore_index=True,
    )

# %%
# Construir new_poems_df
if not (poems_processed_cache.is_file() and not FORCE_REBUILD_PROCESSED_CACHE):

    column_name: List[str] = [
        "title",
        "title_raw",
        "poet",
        "poem",
        "tags",
        "source",
        "corpus_role",
        "poem_raw",
        "poem_processed",
    ]

    new_poems_df: PandasDF = (
        pd.concat(
            [
                poetry_df[column_name],
                external_poems_df[column_name],
            ],
            ignore_index=True,
        )
        .dropna(subset=["title", "poem_processed"])
        .reset_index(drop=True)
    )

    new_poems_df.to_csv(
        str(poems_processed_cache),
        **setup_save_pipe,
    )

    print(f"Cache combinado generado: {poems_processed_cache}")

display(new_poems_df.head(5))
print(new_poems_df.shape)

display(
        pd.DataFrame(
        new_poems_df[["corpus_role", "source", "poet"]]
        .value_counts()
        .head(20)
    )
)
# Out:
#                                 title              poet  \
# 0  objects used to prop open a window  Michelle Menting
# 1                      the new church     Lucia Cherciu
# 2                         look for me        Ted Kooser
# 3                           wild life   Grace Cavalieri
# 4                            umbrella      Connie Wanek
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             poem  \
# 0                                                                                                                                                                                                                                                                                                                                                                                     \r\r\nDog bone, stapler,\r\r\ncribbage board, garlic press\r\r\n     because this window is loose—lacks\r\r\nsuction, lacks grip.\r\r\nBungee cord, bootstrap,\r\r\ndog leash, leather belt\r\r\n     because this window had sash cords.\r\r\nThey frayed. They broke.\r\r\nFeather duster, thatch of straw, empty\r\r\nbottle of Elmer's glue\r\r\n     because this window is loud—its hinges clack\r\r\nopen, clack shut.\r\r\nStuffed bear, baby blanket,\r\r\nsingle crib newel\r\r\n     because this window is split. It's dividing\r\r\nin two.\r\r\nVelvet moss, sagebrush,\r\r\nwillow branch, robin's wing\r\r\n     because this window, it's pane-less. It's only\r\r\na frame of air.\r\r\n
# 1                                                                                                                                                                                                                                                                                                                                 \r\r\nThe old cupola glinted above the clouds, shone\r\r\namong fir trees, but it took him an hour\r\r\nfor the half mile all the way up the hill. As he trailed,\r\r\nthe village passed him by, greeted him,\r\r\nasked about his health, but everybody hurried\r\r\nto catch the mass, left him leaning against fences,\r\r\nmeasuring the road with the walking stick he sculpted.\r\r\nHe yearned for the day when the new church\r\r\nwould be built—right across the road. Now\r\r\nit rises above the moon: saints in frescoes\r\r\nmeet the eye, and only the rain has started to cut\r\r\nthrough the shingles on the roof of his empty\r\r\nhouse. The apple trees have taken over the sky,\r\r\nsequestered the gate, sidled over the porch.\r\r\n
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       \r\r\nLook for me under the hood\r\r\nof that old Chevrolet settled in weeds\r\r\nat the end of the pasture.\r\r\nI'm the radiator that spent its years\r\r\nbolted in front of an engine\r\r\nshoving me forward into the wind.\r\r\nWhatever was in me in those days\r\r\nhas mostly leaked away,\r\r\nbut my cap's still screwed on tight\r\r\nand I know the names of all these\r\r\ntattered moths and broken grasshoppers\r\r\nthe rest of you've forgotten.\r\r\n
# 3  \r\r\nBehind the silo, the Mother Rabbit\r\r\nhunches like a giant spider with strange calm:\r\r\nsix tiny babies beneath, each\r\r\nclamoring for a sweet syringe of milk.\r\r\nThis may sound cute to you, reading\r\r\nfrom your pulpit of plenty,\r\r\nbut one small one was left out of reach,\r\r\na knife of fur\r\r\nbarging between the others.\r\r\nI watched behind a turret of sand. If\r\r\nI could have cautioned the mother rabbit\r\r\nI would. If I could summon the\r\r\nBunnies to fit him in beneath\r\r\nthe belly's swell\r\r\nI would. But instead, I stood frozen, wishing\r\r\nfor some equity. This must be\r\r\nwhy it's called Wild Life because of all the\r\r\ncrazed emotions tangled up in\r\r\nthe underbrush within us.\r\r\nDid I tell you how\r\r\nthe smallest one, black and trembling,\r\r\nhopped behind the kudzu\r\r\nstill filigreed with wanting?\r\r\nShould we talk now of animal heritage, their species,\r\r\ncreature development? And what do we say\r\r\nabout form and focus—\r\r\nwriting this when a stray goes hungry, and away.\r\r\n
# 4                                                                                                                                                                                                                                                                                       \r\r\nWhen I push your button\r\r\nyou fly off the handle,\r\r\nold skin and bones,\r\r\nblack bat wing.\r\r\nWe're alike, you and I.\r\r\nBoth of us\r\r\nresemble my mother,\r\r\nso fierce in her advocacy\r\r\non behalf of\r\r\nthe most vulnerable child\r\r\nwho'll catch his death\r\r\nin this tempest.\r\r\nSuch a headwind!\r\r\nSometimes it requires\r\r\nall my strength\r\r\njust to end a line.\r\r\nBut when the wind is at\r\r\nmy back, we're likely\r\r\nto get carried away, and say\r\r\nsomething we can never retract,\r\r\nsomething saturated from the ribs\r\r\ndown, an old stony\r\r\nword like ruin. You're what roof\r\r\nI have, frail thing,\r\r\nyou're my argument\r\r\nagainst the whole sky.\r\r\nYou're the fundamental difference\r\r\nbetween wet and dry.\r\r\n
#
#   tags             source corpus_role  \
# 0   []  poetry_foundation   reference
# 1   []  poetry_foundation   reference
# 2   []  poetry_foundation   reference
# 3   []  poetry_foundation   reference
# 4   []  poetry_foundation   reference
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         poem_raw  \
# 0                                                                                                                                                                                                                                                                                                                                                                                     \r\r\nDog bone, stapler,\r\r\ncribbage board, garlic press\r\r\n     because this window is loose—lacks\r\r\nsuction, lacks grip.\r\r\nBungee cord, bootstrap,\r\r\ndog leash, leather belt\r\r\n     because this window had sash cords.\r\r\nThey frayed. They broke.\r\r\nFeather duster, thatch of straw, empty\r\r\nbottle of Elmer's glue\r\r\n     because this window is loud—its hinges clack\r\r\nopen, clack shut.\r\r\nStuffed bear, baby blanket,\r\r\nsingle crib newel\r\r\n     because this window is split. It's dividing\r\r\nin two.\r\r\nVelvet moss, sagebrush,\r\r\nwillow branch, robin's wing\r\r\n     because this window, it's pane-less. It's only\r\r\na frame of air.\r\r\n
# 1                                                                                                                                                                                                                                                                                                                                 \r\r\nThe old cupola glinted above the clouds, shone\r\r\namong fir trees, but it took him an hour\r\r\nfor the half mile all the way up the hill. As he trailed,\r\r\nthe village passed him by, greeted him,\r\r\nasked about his health, but everybody hurried\r\r\nto catch the mass, left him leaning against fences,\r\r\nmeasuring the road with the walking stick he sculpted.\r\r\nHe yearned for the day when the new church\r\r\nwould be built—right across the road. Now\r\r\nit rises above the moon: saints in frescoes\r\r\nmeet the eye, and only the rain has started to cut\r\r\nthrough the shingles on the roof of his empty\r\r\nhouse. The apple trees have taken over the sky,\r\r\nsequestered the gate, sidled over the porch.\r\r\n
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       \r\r\nLook for me under the hood\r\r\nof that old Chevrolet settled in weeds\r\r\nat the end of the pasture.\r\r\nI'm the radiator that spent its years\r\r\nbolted in front of an engine\r\r\nshoving me forward into the wind.\r\r\nWhatever was in me in those days\r\r\nhas mostly leaked away,\r\r\nbut my cap's still screwed on tight\r\r\nand I know the names of all these\r\r\ntattered moths and broken grasshoppers\r\r\nthe rest of you've forgotten.\r\r\n
# 3  \r\r\nBehind the silo, the Mother Rabbit\r\r\nhunches like a giant spider with strange calm:\r\r\nsix tiny babies beneath, each\r\r\nclamoring for a sweet syringe of milk.\r\r\nThis may sound cute to you, reading\r\r\nfrom your pulpit of plenty,\r\r\nbut one small one was left out of reach,\r\r\na knife of fur\r\r\nbarging between the others.\r\r\nI watched behind a turret of sand. If\r\r\nI could have cautioned the mother rabbit\r\r\nI would. If I could summon the\r\r\nBunnies to fit him in beneath\r\r\nthe belly's swell\r\r\nI would. But instead, I stood frozen, wishing\r\r\nfor some equity. This must be\r\r\nwhy it's called Wild Life because of all the\r\r\ncrazed emotions tangled up in\r\r\nthe underbrush within us.\r\r\nDid I tell you how\r\r\nthe smallest one, black and trembling,\r\r\nhopped behind the kudzu\r\r\nstill filigreed with wanting?\r\r\nShould we talk now of animal heritage, their species,\r\r\ncreature development? And what do we say\r\r\nabout form and focus—\r\r\nwriting this when a stray goes hungry, and away.\r\r\n
# 4                                                                                                                                                                                                                                                                                       \r\r\nWhen I push your button\r\r\nyou fly off the handle,\r\r\nold skin and bones,\r\r\nblack bat wing.\r\r\nWe're alike, you and I.\r\r\nBoth of us\r\r\nresemble my mother,\r\r\nso fierce in her advocacy\r\r\non behalf of\r\r\nthe most vulnerable child\r\r\nwho'll catch his death\r\r\nin this tempest.\r\r\nSuch a headwind!\r\r\nSometimes it requires\r\r\nall my strength\r\r\njust to end a line.\r\r\nBut when the wind is at\r\r\nmy back, we're likely\r\r\nto get carried away, and say\r\r\nsomething we can never retract,\r\r\nsomething saturated from the ribs\r\r\ndown, an old stony\r\r\nword like ruin. You're what roof\r\r\nI have, frail thing,\r\r\nyou're my argument\r\r\nagainst the whole sky.\r\r\nYou're the fundamental difference\r\r\nbetween wet and dry.\r\r\n
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                           poem_processed  \
# 0                                                                         dog bone stapler cribbag board garlic press window looselack suction lack grip bunge cord bootstrap dog leash leather belt window sash cord fray break feather duster thatch straw bottl elmer glue window loudit he clack open clack shut stuf bear babi blanket singl crib newel window split divid velvet moss sagebrush willow branch robin wing window paneless frame air
# 1                                                                                                                         old cupola glint cloud shone fir tree take hour half mile way hill trail villag pass greet ask health everybodi hurri catch mass leave lean fenc measur road walk stick sculpt yearn day new church builtright road rise moon saint fresco meet eye rain start cut shingl roof hous appl tree take sky sequest gate sidl porch
# 2                                                                                                                                                                                                                                                                     look hood old chevrolet settl weed end pastur m radiat spend year bolt engin shove forward wind day leak away cap screw tight know name tatter moth break grasshopp rest ve forget
# 3  silo mother rabbit hunch like giant spider strang calm tini babi beneath clamor sweet syring milk sound cute read pulpit plenti small left reach knife fur barg watch turret sand caution mother rabbit summon bunni fit beneath belli swell instead stand frozen wish equiti call wild life craze emot tangl underbrush tell small black trembl hop kudzu filigre want talk anim heritag speci creatur develop form focu write stray goe hungri away
# 4                                                                                                                                                              push button fli handl old skin bone black bat wing alik resembl mother fierc advocaci behalf vulner child ll catch death tempest headwind requir strength end line wind like carri away retract satur rib old stoni word like ruin roof frail thing argument sky fundament differ wet dri
#
#                                                                             title_raw
# 0  \r\r\n                    Objects Used to Prop Open a Window\r\r\n
# 1                      \r\r\n                    The New Church\r\r\n
# 2                         \r\r\n                    Look for Me\r\r\n
# 3                           \r\r\n                    Wild Life\r\r\n
# 4                            \r\r\n                    Umbrella\r\r\n
# (13858, 9)
#                                                           count
# corpus_role source            poet
# reference   poetry_foundation William Shakespeare            85
#                               Alfred, Lord Tennyson          73
#                               William Wordsworth             51
#                               Emily Dickinson                51
#                               Rae Armantrout                 49
#                               Yusef Komunyakaa               42
#                               John Ashbery                   42
#                               William Butler Yeats           41
#                               John Donne                     38
#                               Robert Browning                35
#                               Percy Bysshe Shelley           35
#                               Algernon Charles Swinburne     35
#                               Walt Whitman                   35
#                               Kay Ryan                       34
#                               John Milton                    33
#                               Edmund Spenser                 33
#                               Samuel Menashe                 33
#                               William Blake                  33
#                               Edward Thomas                  32
#                               Thomas Hardy                   32
