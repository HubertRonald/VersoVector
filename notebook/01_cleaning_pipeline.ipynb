# %% [markdown]
# # 01 · Cleaning pipeline
#
# Este notebook prepara el corpus común del proyecto. Su salida principal es `data/poems_processed.csv`, que funciona como cache de texto procesado para evitar repetir `spaCy` en cada notebook.
#
# Para una visualización completa, se recomienda usar **nbviewer**:
#
# Prepara el corpus base y los corpus externos para los notebooks posteriores.
#
# Este notebook:
#
# - carga `PoetryFoundationData.csv`;
# - carga corpus externos como César Vallejo;
# - normaliza metadata (`title`, `poet`, `tags`);
# - conserva trazabilidad (`title_raw`, `poet_raw`, `poem_raw`);
# - genera `poem_processed`;
# - crea un identificador único `poem_id`;
# - guarda `data/CleanedPoetryFoundationData.csv`;
# - guarda `data/poems_processed.csv`.
#
# La columna `poem_id` es la llave técnica que usarán los notebooks 02, 03, 04 y 05.
#
# - [01_cleaning_pipeline.ipynb (nbviewer)](https://nbviewer.org/github/HubertRonald/VersoVector/blob/main/notebook/01_cleaning_pipeline.ipynb)

# %%
from __future__ import annotations
import sys
from pathlib import Path

# Permite importar modules/ y utils/ cuando el notebook se ejecuta desde notebook/
sys.path.insert(0, '..')

# %load_ext autoreload
# %autoreload 2

# python
import csv
import os
import ssl

import pandas as pd
from inspect import cleandoc

# utils, modules
from utils import Constants, make_short_hash
from modules.preprocessing import (
    preprocess, 
    normalize_poetry_columns
)
from modules.io import data_path, display_path

# typings
from pandas import DataFrame as PandasDF
from typing import Dict, List

# setup
pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('max_colwidth', None)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## 1. Configuración de rutas y fuentes

# %%
# cargar el dataset sklearn
if not os.environ.get('CI'):
    ssl._create_default_https_context =\
        ssl._create_unverified_context

# input base
poetry_foundation_data: Path = data_path("PoetryFoundationData.csv")
external_poetry_sources: List[Dict] = [
    {
        "path": data_path("vallejo_poems_en.csv"),
        "source": "cesar_vallejo",
        "poet": "César Vallejo",
        "corpus_role": "external",
    },
    # Ejemplo futuro:
    # {
    #     "path": data_path("valera_poems_en.csv"),
    #     "source": "blanca_valera",
    #     "poet": "Blanca Valera",
    #     "corpus_role": "external",
    # },
]

# outputs / cache
poetry_foundation_cleaned: Path = data_path("CleanedPoetryFoundationData.csv")
poems_processed_cache: Path = data_path("poems_processed.csv")

# %%
setup_load_input: Dict = dict(
    sep=Constants.COMMA_STR,
    encoding=Constants.ENCODING,
)

setup_load_pipe: Dict = dict(
    sep=Constants.PIPE_STR,
    quotechar=Constants.QUOTECHAR_STR,
    quoting=csv.QUOTE_NONNUMERIC,
    encoding=Constants.ENCODING,
)

setup_save_pipe: Dict = dict(
    sep=Constants.PIPE_STR,
    quotechar=Constants.QUOTECHAR_STR,
    quoting=csv.QUOTE_NONNUMERIC,
    encoding=Constants.ENCODING,
    index=False,
)

# Cambiar a True cuando se modifique la lógica de limpieza o identidad.
FORCE_REBUILD_POETRY_CLEANED: bool = False
FORCE_REBUILD_PROCESSED_CACHE: bool = False

USE_PROCESSED_CACHE: bool = (
    poems_processed_cache.is_file()
    and not FORCE_REBUILD_PROCESSED_CACHE
    and not FORCE_REBUILD_POETRY_CLEANED
)

# %% [markdown]
# ## 2. Funciones auxiliares del notebook

# %%
def save_pipe_csv(df: pd.DataFrame, path: Path) -> None:
    """Guarda un DataFrame con la configuración estándar del proyecto."""
    df.to_csv(
        str(path),
        **setup_save_pipe,
    )


def ensure_source_columns(
        df: pd.DataFrame,
        source: str,
        corpus_role: str,
    ) -> pd.DataFrame:
    """Garantiza columnas de fuente y rol del corpus."""
    df = df.copy()

    if "source" not in df.columns:
        df["source"] = source
    else:
        df["source"] = df["source"].fillna(source).astype(str)

    if "corpus_role" not in df.columns:
        df["corpus_role"] = corpus_role
    else:
        df["corpus_role"] = df["corpus_role"].fillna(corpus_role).astype(str)

    return df


def ensure_poem_processed(
        df: pd.DataFrame,
        label: str,
        output_path: Path | None = None,
    ) -> pd.DataFrame:
    """
    Garantiza poem_processed procesando únicamente filas faltantes.

    Esto evita reprocesar todo el corpus cuando solo faltan algunas filas.
    """
    df = df.copy()

    if "poem_raw" not in df.columns:
        if "poem" not in df.columns:
            raise ValueError(f"{label} no tiene columna poem ni poem_raw.")
        df["poem_raw"] = df["poem"].astype(str)

    if "poem_processed" not in df.columns:
        df["poem_processed"] = ""

    missing_processed_mask = (
        df["poem_processed"].isna()
        | df["poem_processed"].astype(str).str.strip().eq("")
    )

    if missing_processed_mask.any():
        print(
            f"Se procesarán {missing_processed_mask.sum()} poemas "
            f"de {label} sin poem_processed..."
        )

        df.loc[missing_processed_mask, "poem_processed"] = (
            df.loc[missing_processed_mask, "poem_raw"]
            .astype(str)
            .apply(preprocess)
        )

        if output_path is not None:
            save_pipe_csv(df, output_path)
            print(f"Archivo actualizado: {display_path(output_path)}")

    return df


def add_poem_identity(
        df: pd.DataFrame,
        force: bool = False,
    ) -> pd.DataFrame:
    """
    Agrega una llave técnica única por poema.

    Columnas generadas:
    - source_row_id: consecutivo por fuente
    - poem_hash: hash corto de metadata + texto
    - poem_id: llave única estable para integraciones posteriores

    La llave evita unir por title/poet, porque esos campos pueden repetirse.
    """
    df = df.copy().reset_index(drop=True)

    if (
        not force
        and "poem_id" in df.columns
        and not df["poem_id"].isna().any()
        and not df["poem_id"].duplicated().any()
    ):
        return df

    required_for_identity = [
        "source",
        "poet_raw",
        "title_raw",
        "poem_raw",
    ]

    missing = [
        col
        for col in required_for_identity
        if col not in df.columns
    ]

    if missing:
        raise ValueError(
            f"No se puede generar poem_id. Faltan columnas: {missing}"
        )

    df["source_row_id"] = (
        df
        .groupby("source", dropna=False)
        .cumcount()
    )

    identity_text = (
        df["source"].astype(str)
        + "||"
        + df["source_row_id"].astype(str)
        + "||"
        + df["poet_raw"].astype(str)
        + "||"
        + df["title_raw"].astype(str)
        + "||"
        + df["poem_raw"].astype(str)
    )

    df["poem_hash"] = identity_text.apply(make_short_hash)

    df["poem_id"] = (
        df["source"].astype(str)
        + "::"
        + df["source_row_id"].astype(str).str.zfill(6)
        + "::"
        + df["poem_hash"].astype(str)
    )

    if df["poem_id"].duplicated().any():
        duplicated = df.loc[
            df["poem_id"].duplicated(keep=False),
            [
                "poem_id",
                "title",
                "poet",
                "source",
                "source_row_id",
            ],
        ]

        raise ValueError(
            "poem_id no es único. Muestra de duplicados:\n"
            f"{duplicated.head(20)}"
        )

    return df


def validate_processed_schema(df: pd.DataFrame) -> None:
    """Valida columnas mínimas del cache final."""
    required_columns = {
        "poem_id",
        "source_row_id",
        "poem_hash",
        "title",
        "title_raw",
        "poet",
        "poet_raw",
        "poem",
        "tags",
        "source",
        "corpus_role",
        "poem_raw",
        "poem_processed",
    }

    missing_columns = required_columns.difference(df.columns)

    if missing_columns:
        raise ValueError(
            f"Faltan columnas requeridas en poems_processed: {missing_columns}"
        )

    if df["poem_id"].duplicated().any():
        raise ValueError("poem_id tiene duplicados en poems_processed.")

    if df["poem_processed"].isna().any():
        raise ValueError("poem_processed contiene nulos.")

# %% [markdown]
# ## 3. Cargar cache final si existe

# %%
# intentar cargar el cache final
if USE_PROCESSED_CACHE:
    print(f"Cargando cache combinado existente: {display_path(poems_processed_cache)}")

    new_poems_df: PandasDF = pd.read_csv(
        str(poems_processed_cache),
        **setup_load_pipe,
    )

    # Normaliza title/poet/poem/tags sin reprocesar poem_processed.
    new_poems_df = normalize_poetry_columns(new_poems_df)

    new_poems_df = ensure_source_columns(
        new_poems_df,
        source=Constants.UNKNOWN,
        corpus_role=Constants.UNKNOWN,
    )

    new_poems_df = ensure_poem_processed(
        new_poems_df,
        label="cache combinado",
        output_path=None,
    )

    # Si el cache viejo no tenía poem_id, se genera y se actualiza.
    had_poem_id = (
        "poem_id" in new_poems_df.columns
        and not new_poems_df["poem_id"].isna().any()
        and not new_poems_df["poem_id"].duplicated().any()
    )

    new_poems_df = add_poem_identity(
        new_poems_df,
        force=not had_poem_id,
    )

    validate_processed_schema(new_poems_df)

    if not had_poem_id:
        save_pipe_csv(new_poems_df, poems_processed_cache)
        print(f"Cache actualizado con poem_id: {display_path(poems_processed_cache)}")

# %% [markdown]
# ## 4. Construir cache desde fuentes si no existe o si se fuerza rebuild

# %%
# Asegurar columnas sin reprocesar de mas
if not USE_PROCESSED_CACHE:
    print(
        "No existe cache combinado o se solicitó reconstrucción. "
        "Se construirá desde archivos fuente..."
    )

    if not poetry_foundation_data.is_file():
        raise FileNotFoundError(
            cleandoc(f"""
            El archivo {display_path(poetry_foundation_data)} no existe.

            Por favor, descargue PoetryFoundationData.csv desde Kaggle
            y colóquelo en la carpeta ./data/
            """)
        )

    missing_external_files = [
        item["path"]
        for item in external_poetry_sources
        if not item["path"].is_file()
    ]

    if missing_external_files:
        missing_display = [
            display_path(path)
            for path in missing_external_files
        ]

        raise FileNotFoundError(
            cleandoc(f"""
            No existen los siguientes archivos externos:

            {missing_display}

            Verifique que estén disponibles en ./data/
            """)
        )
# Out:
# No existe cache combinado o se solicitó reconstrucción. Se construirá desde archivos fuente...

# %% [markdown]
# ## 5. Procesar Poetry Foundation

# %%
# Cargar poetas externos de forma general
if not USE_PROCESSED_CACHE:

    if poetry_foundation_cleaned.is_file() and not FORCE_REBUILD_POETRY_CLEANED:
        print(
            "Cargando Poetry Foundation limpio desde: "
            f"{display_path(poetry_foundation_cleaned)}"
        )

        poetry_df: PandasDF = pd.read_csv(
            str(poetry_foundation_cleaned),
            **setup_load_pipe,
        )

        poetry_df = normalize_poetry_columns(poetry_df)

    else:
        print("Procesando PoetryFoundationData.csv desde archivo crudo...")

        poetry_df: PandasDF = (
            pd.read_csv(
                poetry_foundation_data,
                usecols=lambda col: "unnamed" not in col.lower(),
                **setup_load_input,
            )
            .dropna(subset=["Title", "Poem"])
            .reset_index(drop=True)
        )

        poetry_df = normalize_poetry_columns(poetry_df)

    poetry_df = ensure_source_columns(
        poetry_df,
        source="poetry_foundation",
        corpus_role="reference",
    )

    poetry_df = ensure_poem_processed(
        poetry_df,
        label="Poetry Foundation",
        output_path=poetry_foundation_cleaned,
    )

    save_pipe_csv(poetry_df, poetry_foundation_cleaned)

    print(f"Archivo limpio disponible: {display_path(poetry_foundation_cleaned)}")

    display(poetry_df.head(3))
    print(poetry_df.shape)
# Out:
# Procesando PoetryFoundationData.csv desde archivo crudo...
# Se procesarán 13854 poemas de Poetry Foundation sin poem_processed...
# Archivo actualizado: /VersoVector/data/CleanedPoetryFoundationData.csv
# Archivo limpio disponible: /VersoVector/data/CleanedPoetryFoundationData.csv
#                                 title  \
# 0  objects used to prop open a window
# 1                      the new church
# 2                         look for me
#
# ...

# %% [markdown]
# ## 6. Procesar corpus externos

# %%
if not USE_PROCESSED_CACHE:

    external_frames: List[PandasDF] = []

    for item in external_poetry_sources:
        print(f"Procesando corpus externo: {item['source']}")

        external_df: PandasDF = pd.read_csv(
            str(item["path"]),
            **setup_load_pipe,
        )

        external_df = external_df.rename(
            columns={
                col: (
                    col
                    .strip()
                    .lower()
                    .replace(Constants.SPACE_STR, Constants.UNDERLINE)
                )
                for col in external_df.columns
            }
        )

        external_df = (
            external_df
            .dropna(subset=["title", "poem"])
            .reset_index(drop=True)
        )

        # Metadata externa antes de normalizar.
        external_df["poet"] = item["poet"]
        external_df["tags"] = [[] for _ in range(len(external_df))]

        external_df = normalize_poetry_columns(external_df)

        external_df = ensure_source_columns(
            external_df,
            source=item["source"],
            corpus_role=item.get("corpus_role", "external"),
        )

        external_df = ensure_poem_processed(
            external_df,
            label=item["source"],
            output_path=None,
        )

        external_frames.append(external_df)

    external_poems_df: PandasDF = (
        pd.concat(
            external_frames,
            ignore_index=True,
        )
        if external_frames
        else pd.DataFrame()
    )

    display(external_poems_df.head(3))
    print(external_poems_df.shape)
# Out:
# Procesando corpus externo: cesar_vallejo
# Se procesarán 4 poemas de cesar_vallejo sin poem_processed...
#                                  title  \
# 0                    the black heralds
# 1  black stone on top of a white stone
# 2                   paris october poem
#
# ...

# %% [markdown]
# ## 7. Construir `poems_processed.csv`

# %%
if not USE_PROCESSED_CACHE:

    column_name: List[str] = [
        "title",
        "title_raw",
        "poet",
        "poet_raw",
        "poem",
        "tags",
        "source",
        "corpus_role",
        "poem_raw",
        "poem_processed",
    ]

    frames_to_concat: List[PandasDF] = [
        poetry_df[column_name],
    ]

    if not external_poems_df.empty:
        frames_to_concat.append(external_poems_df[column_name])

    new_poems_df: PandasDF = (
        pd.concat(
            frames_to_concat,
            ignore_index=True,
        )
        .dropna(subset=["title", "poem_processed"])
        .reset_index(drop=True)
    )

    new_poems_df = add_poem_identity(
        new_poems_df,
        force=True,
    )

    final_column_order: List[str] = [
        "poem_id",
        "source_row_id",
        "poem_hash",
        "title",
        "title_raw",
        "poet",
        "poet_raw",
        "poem",
        "tags",
        "source",
        "corpus_role",
        "poem_raw",
        "poem_processed",
    ]

    new_poems_df = new_poems_df[final_column_order]

    validate_processed_schema(new_poems_df)

    save_pipe_csv(
        new_poems_df,
        poems_processed_cache,
    )

    print(f"Cache combinado generado: {display_path(poems_processed_cache)}")
# Out:
# Cache combinado generado: /VersoVector/data/poems_processed.csv

# %% [markdown]
# ## 8. Validaciones finales

# %%
display(new_poems_df.head(3))
print(new_poems_df.shape)
# Out:
#                                    poem_id  source_row_id     poem_hash  \
# 0  poetry_foundation::000000::d1e86366cdbb              0  d1e86366cdbb
# 1  poetry_foundation::000001::0dbfeaec7a94              1  0dbfeaec7a94
# 2  poetry_foundation::000002::52eddc66be9e              2  52eddc66be9e
#
#                                 title  \
# 0  objects used to prop open a window
# 1                      the new church
# 2                         look for me
#
#                                                                             title_raw  \
# 0  \r\r\n                    Objects Used to Prop Open a Window\r\r\n
# 1                      \r\r\n                    The New Church\r\r\n
# 2                         \r\r\n                    Look for Me\r\r\n
#
#                poet          poet_raw  \
# 0  michelle menting  Michelle Menting
# 1     lucia cherciu     Lucia Cherciu
# 2        ted kooser        Ted Kooser
#
# ...

# %%
display(
    pd.DataFrame(
        new_poems_df[
            [
                "corpus_role",
                "source",
                "poet",
            ]
        ]
        .value_counts()
        .head(20)
    )
)
# Out:
#                                                           count
# corpus_role source            poet
# reference   poetry_foundation william shakespeare            85
#                               alfred lord tennyson           73
#                               william wordsworth             51
#                               emily dickinson                51
#                               rae armantrout                 49
#                               john ashbery                   42
#                               yusef komunyakaa               42
#                               william butler yeats           41
#                               john donne                     38
#                               percy bysshe shelley           35
#                               algernon charles swinburne     35
#                               walt whitman                   35
#                               robert browning                35
# ...

# %%
display(
    new_poems_df[
        [
            "poem_id",
            "title",
            "poet",
            "source",
            "corpus_role",
        ]
    ].head(10)
)
# Out:
#                                    poem_id  \
# 0  poetry_foundation::000000::d1e86366cdbb
# 1  poetry_foundation::000001::0dbfeaec7a94
# 2  poetry_foundation::000002::52eddc66be9e
# 3  poetry_foundation::000003::cb913747f0bf
# 4  poetry_foundation::000004::7a327c97cdf6
# 5  poetry_foundation::000005::7e12180ce611
# 6  poetry_foundation::000006::8c930bbca869
# 7  poetry_foundation::000007::201eb0461240
# 8  poetry_foundation::000008::8b99c04285d7
# 9  poetry_foundation::000009::eaaa80a8c462
#
#                                  title                poet             source  \
# 0   objects used to prop open a window    michelle menting  poetry_foundation
# 1                       the new church       lucia cherciu  poetry_foundation
# 2                          look for me          ted kooser  poetry_foundation
# 3                            wild life     grace cavalieri  poetry_foundation
# 4                             umbrella        connie wanek  poetry_foundation
# ...

# %%
print("poem_id únicos:", new_poems_df["poem_id"].is_unique)
print("n filas:", len(new_poems_df))
print("n poem_id:", new_poems_df["poem_id"].nunique())
# Out:
# poem_id únicos: True
# n filas: 13858
# n poem_id: 13858

# %% [markdown]
# ## 9. Nota para notebooks posteriores
#
# A partir de este punto, los notebooks posteriores deben conservar `poem_id`:
#
# - `02_feature_pipeline.ipynb` guarda `poem_id` en `reference_metadata.csv` y `external_metadata.csv`.
# - `03_embeddings_supervised.ipynb` guarda `poem_id` en `supervised_predictions.csv`.
# - `04_embeddings_unsupervised.ipynb` guarda `poem_id` en `unsupervised_results.csv`.
# - `05_supervised_unsupervised_integration.ipynb` integra usando `key_cols=["poem_id"]`.
